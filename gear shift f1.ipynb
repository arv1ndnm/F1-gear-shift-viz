# %%
import fastf1 as ff1
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib import cm
import numpy as np
ff1.Cache.enable_cache(r'C:\Users\Arvind\Documents\formula_1\cache')

# %%
session = ff1.get_session(2022, 17, 'R')
laps = session.load_laps(with_telemetry=True)

lap = laps.pick_fastest()
tel = lap.get_telemetry()
x = np.array(tel['X'].values)
y = np.array(tel['Y'].values)
#z = np.array(tel['Z'].values)

points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)
gear = tel['nGear'].to_numpy().astype(float)
cmap = cm.get_cmap('Paired')
lc_comp = LineCollection(segments, norm=plt.Normalize(1, cmap.N+1), cmap=cmap)
lc_comp.set_array(gear)
lc_comp.set_linewidth(3)
plt.gca().add_collection(lc_comp)
plt.axis('equal')
plt.tick_params(labelleft=False, left=False, labelbottom=False, bottom=False)

title = plt.suptitle(
    f"Fastest Lap Gear Shift Visualization\n"
    f"{lap['Driver']} - {session.weekend.name} {session.weekend.year}"
)
cbar = plt.colorbar(mappable=lc_comp, label="Gear", boundaries=np.arange(1, 10))
cbar.set_ticks(np.arange(1.5, 9.5))
cbar.set_ticklabels(np.arange(1, 9))

plt.show()
# Out:
# core           INFO 	Loading laps for Singapore Grand Prix - Race [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['6', '44', '63', '1', '18', '20', '11', '10', '3', '22', '47', '55', '14', '4', '31', '24', '5', '16', '23', '77']

# %%
session = ff1.get_session(2020,'abu dhabi', 'R')
laps = session.load_laps(with_telemetry=True)

lap = laps.pick_fastest()
tel = lap.get_telemetry()
x = np.array(tel['X'].values)
y = np.array(tel['Y'].values)
#z = np.array(tel['Z'].values)

points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)
gear = tel['nGear'].to_numpy().astype(float)
cmap = cm.get_cmap('Paired')
lc_comp = LineCollection(segments, norm=plt.Normalize(1, cmap.N+1), cmap=cmap)
lc_comp.set_array(gear)
lc_comp.set_linewidth(3)
plt.gca().add_collection(lc_comp)
plt.axis('equal')
plt.tick_params(labelleft=False, left=False, labelbottom=False, bottom=False)

title = plt.suptitle(
    f"Fastest Lap Gear Shift Visualization\n"
    f"{lap['Driver']} - {session.weekend.name} {session.weekend.year}"
)
cbar = plt.colorbar(mappable=lc_comp, label="Gear", boundaries=np.arange(1, 10))
cbar.set_ticks(np.arange(1.5, 9.5))
cbar.set_ticklabels(np.arange(1, 9))

plt.show()
# Out:
# core           INFO 	Loading laps for Abu Dhabi Grand Prix - Race [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['77', '31', '26', '4', '3', '16', '18', '23', '33', '5', '55', '99', '7', '6', '11', '20', '10', '51', '63', '44']

# %%
laps.pick_driver('VER').get_telemetry()
# Out:
#                          Date            SessionTime DriverAhead  \
# 2     2021-12-12 13:03:21.881 0 days 01:02:21.871000
# 3     2021-12-12 13:03:21.921 0 days 01:02:21.911000
# 4     2021-12-12 13:03:21.969 0 days 01:02:21.959000
# 5     2021-12-12 13:03:22.141 0 days 01:02:22.131000
# 6     2021-12-12 13:03:22.209 0 days 01:02:22.199000
# ...                       ...                    ...         ...
# 47399 2021-12-12 14:33:39.010        0 days 02:32:39          55
# 47400 2021-12-12 14:33:39.182 0 days 02:32:39.172000          55
# 47401 2021-12-12 14:33:39.249 0 days 02:32:39.239000          55
# 47402 2021-12-12 14:33:39.402 0 days 02:32:39.392000          55
# 47403 2021-12-12 14:33:39.422 0 days 02:32:39.412000          55
#
#        DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                   0.200000        0 days 00:00:00  11074      0      1
# 3                   0.200000 0 days 00:00:00.040000  11066      0      1
# ...

# %%
tot_ver = pd.DataFrame()
tot_per = pd.DataFrame()
tot_ham = pd.DataFrame()
laps_ver = laps.pick_driver('VER')
laps_per = laps.pick_driver('PER')
laps_ham = laps.pick_driver('HAM')
max_laps = laps_ver['LapNumber'].max()
for i in range(1,max_laps+1):
    # -------------verstappen-----------
    v = laps_ver[laps_ver.LapNumber ==i].get_telemetry()
    v['Lap'] = i
    tot_ver = tot_ver.append(v)
    #-----------------perez-----------
    if(i<=laps.pick_driver('PER')['LapNumber'].max()):
        p = laps_per[laps_per.LapNumber ==i].get_telemetry()
        p['Lap'] = i
        tot_per = tot_per.append(p)
    # ----------------hamilton-----------
    h = laps_ham[laps_ham.LapNumber ==i].get_telemetry()
    h['Lap'] = i
    tot_ham = tot_ham.append(h)
#     total_laps_ver['Lap'] = i
    print(i)
# Out:
# <ipython-input-34-e85059812455>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tot_ver = tot_ver.append(v)
# <ipython-input-34-e85059812455>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tot_per = tot_per.append(p)
# <ipython-input-34-e85059812455>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tot_ham = tot_ham.append(h)
# 1
# <ipython-input-34-e85059812455>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tot_ver = tot_ver.append(v)
# <ipython-input-34-e85059812455>:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
total_laps_ver
# Out:
#                         Date            SessionTime DriverAhead  \
# 2    2021-12-12 13:03:21.881 0 days 01:02:21.871000
# 3    2021-12-12 13:03:21.921 0 days 01:02:21.911000
# 4    2021-12-12 13:03:21.969 0 days 01:02:21.959000
# 5    2021-12-12 13:03:22.141 0 days 01:02:22.131000
# 6    2021-12-12 13:03:22.209 0 days 01:02:22.199000
# ...                      ...                    ...         ...
# 1249 2021-12-12 14:32:12.369 0 days 02:31:12.359000          44
# 1250 2021-12-12 14:32:12.522 0 days 02:31:12.512000          44
# 1251 2021-12-12 14:32:12.570 0 days 02:31:12.560000          44
# 1252 2021-12-12 14:32:12.742 0 days 02:31:12.732000          44
# 1253 2021-12-12 14:32:12.804 0 days 02:31:12.794000          44
#
#       DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                  0.200000        0 days 00:00:00  11074      0      1
# 3                  0.200000 0 days 00:00:00.040000  11066      0      1
# ...

# %%
laps_ver[laps_ver.LapNumber ==38].get_telemetry()
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2021-12-12 13:59:16.592 0 days 01:58:16.582000
# 3   2021-12-12 13:59:16.721 0 days 01:58:16.711000
# 4   2021-12-12 13:59:16.764 0 days 01:58:16.754000
# 5   2021-12-12 13:59:16.941 0 days 01:58:16.931000
# 6   2021-12-12 13:59:17.004 0 days 01:58:16.994000          44
# ..                      ...                    ...         ...
# 758 2021-12-12 14:00:42.482 0 days 01:59:42.472000          44
# 759 2021-12-12 14:00:42.605 0 days 01:59:42.595000          44
# 760 2021-12-12 14:00:42.702 0 days 01:59:42.692000          44
# 761 2021-12-12 14:00:42.845 0 days 01:59:42.835000          44
# 762 2021-12-12 14:00:42.913 0 days 01:59:42.903000          44
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2              1156.692500        0 days 00:00:00  11827    230      5
# 3              1156.692500 0 days 00:00:00.129000  11788    231      5
# ...
